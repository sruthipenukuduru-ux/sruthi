# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('C:\\Users\\dell\\Desktop\\jupyter  dataset\\StudentsPerformance.csv',delimiter=',')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data.dropna(axis=0,inplace=True)

# %%
data.isnull().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data['gender'].values
# Out:
# array(['female', 'female', 'female', 'male', 'male', 'female', 'female',
#        'male', 'male', 'female', 'male', 'male', 'female', 'male',
#        'female', 'female', 'male', 'female', 'male', 'female', 'male',
#        'female', 'male', 'female', 'male', 'male', 'male', 'female',
#        'male', 'female', 'female', 'female', 'female', 'male', 'male',
#        'male', 'female', 'female', 'female', 'male', 'male', 'female',
#        'female', 'male', 'female', 'male', 'female', 'female', 'female',
#        'male', 'male', 'male', 'male', 'male', 'female', 'female',
#        'female', 'male', 'male', 'female', 'male', 'male', 'male',
#        'female', 'female', 'male', 'male', 'female', 'male', 'female',
#        'female', 'male', 'female', 'male', 'male', 'male', 'male', 'male',
#        'female', 'female', 'female', 'male', 'male', 'male', 'male',
#        'female', 'female', 'female', 'female', 'female', 'female', 'male',
# ...

# %%
data=data.replace('fare','set',regex=True)
data.head()
data.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data=data.replace('/',"",regex=True)
data
# Out:
#      gender race/ethnicity parental level of education        lunch  \
# 0    female        group B           bachelor's degree     standard
# 1    female        group C                some college     standard
# 2    female        group B             master's degree     standard
# 3      male        group A          associate's degree  freereduced
# 4      male        group C                some college     standard
# ..      ...            ...                         ...          ...
# 995  female        group E             master's degree     standard
# 996    male        group C                 high school  freereduced
# 997  female        group C                 high school  freereduced
# 998  female        group D                some college     standard
# 999  female        group D                some college  freereduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
data
# Out:
#      gender race/ethnicity parental level of education        lunch  \
# 0    female        group B           bachelor's degree     standard
# 1    female        group C                some college     standard
# 2    female        group B             master's degree     standard
# 3      male        group A          associate's degree  freereduced
# 4      male        group C                some college     standard
# ..      ...            ...                         ...          ...
# 995  female        group E             master's degree     standard
# 996    male        group C                 high school  freereduced
# 997  female        group C                 high school  freereduced
# 998  female        group D                some college     standard
# 999  female        group D                some college  freereduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
def value_to_float(s):
    if 'c' in s:
        if len(s) > 1:
          return float(s.replace('c','')) * 95.0
    if 'd' in s:
        if len(s) > 1:
           return float(s.replace('d','')) * 80.0
    if 'b' in s:
        if len(s) > 1:
           return float(s.replace('b','')) * 70.0 
data['math score']=data['math score'].apply(value_to_float)

# %%
display(data[data['math score']>=50])
# Out:
#      gender race/ethnicity parental level of education        lunch  \
# 0    female        group B           bachelor's degree     standard
# 1    female        group C                some college     standard
# 2    female        group B             master's degree     standard
# 4      male        group C                some college     standard
# 5    female        group B          associate's degree     standard
# ..      ...            ...                         ...          ...
# 995  female        group E             master's degree     standard
# 996    male        group C                 high school  freereduced
# 997  female        group C                 high school  freereduced
# 998  female        group D                some college     standard
# 999  female        group D                some college  freereduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
display(data[data.lunch=='standard'])
# Out:
#      gender race/ethnicity parental level of education     lunch  \
# 0    female        group B           bachelor's degree  standard
# 1    female        group C                some college  standard
# 2    female        group B             master's degree  standard
# 4      male        group C                some college  standard
# 5    female        group B          associate's degree  standard
# ..      ...            ...                         ...       ...
# 987    male        group E            some high school  standard
# 991  female        group B            some high school  standard
# 994    male        group A                 high school  standard
# 995  female        group E             master's degree  standard
# 998  female        group D                some college  standard
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.bar(data['gender'],data['math score'])
plt.title('math scores')
plt.ylabel('scores')
plt.gcf().set_size_inches(2,4)
plt.xticks(rotation=80)
plt.show()

# %%
plt.bar(data['gender'],data['math score'],color='green')
plt.title('math scores')
plt.ylabel('scores')
plt.gcf().set_size_inches(2,4)
plt.xticks(rotation=80)
plt.show()

# %%
data['parental level of education']
# Out:
# 0       bachelor's degree
# 1            some college
# 2         master's degree
# 3      associate's degree
# 4            some college
#               ...
# 995       master's degree
# 996           high school
# 997           high school
# 998          some college
# 999          some college
# Name: parental level of education, Length: 1000, dtype: object

# %%
display(data['gender'].value_counts())
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
gender=data['gender'].value_counts().head(8).values
lunch=data['gender'].value_counts().head(8).index
plt.gcf().set_size_inches(2,4)
plt.pie(gender,labels=lunch,autopct="%1.1f%%",wedgeprops={'edgecolor':'green'})
plt.title('ordersd list')
plt.show()

# %%
plt.bar(data['gender'],data['lunch'],color=(data['lunch']>90.8).map({True:'#32a852',False:'#3281a8'}))
plt.xlabel('gender')
plt.ylabel('lunch')
plt.gcf().set_size_inches(2,4)
plt.xticks(rotation=80)
plt.show()
